# %% [markdown]
# ## Data Generation and visualisation for Neural Network

# %%
# !wget https://gist.githubusercontent.com/prateek27/81ef38e7a185f5cecbcb9657f50f8315/raw/91aecb3fba721b227f02d94a07e755a84aa8d795/helper.py
# Out:
# --2019-08-25 11:52:23--  https://gist.githubusercontent.com/prateek27/81ef38e7a185f5cecbcb9657f50f8315/raw/91aecb3fba721b227f02d94a07e755a84aa8d795/helper.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 151.101.36.133
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|151.101.36.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3484 (3.4K) [text/plain]
# Saving to: ‘helper.py’
#
# helper.py           100%[===================>]   3.40K  --.-KB/s    in 0s
#
# 2019-08-25 11:53:06 (25.3 MB/s) - ‘helper.py’ saved [3484/3484]

# %%
# !ls
# Out:
# 'Artificial Neural Network'
#  cb
#  helper.py
#  iit-bbs-workshop-master
#  iit-bbs-workshop-master.zip
#  K-means
# 'Linear Regression'
#  LinearX.npy
#  LinearY.npy
#  LogisticRegression
#  logisticX.csv
#  logisticY.csv
#  ML_Workshop_BasicsOfPython.ipynb
#  ML_Workshop_DataGeneration.ipynb
#  ML_Workshop_DataGenerationVisualisation_ANN.ipynb
#  ML_Workshop_Libraries.ipynb
#  ML_Workshop_LinearRegression.ipynb
#  ML_Workshop_LogisticRegression.ipynb
#  MultivariateRegression
#  perceptron
#  Untitled1.ipynb
#  Untitled2.ipynb
#  Untitled3.ipynb
#  Untitled4.ipynb
#  Untitled5.ipynb
#  Untitled6.ipynb
#  Untitled.ipynb

# %%
from helper import *
import numpy as np 
import matplotlib.pyplot as plt

# %%
X,Y = load_dataset('circles')

# %%
print(X.shape, Y.shape)
# Out:
# (500, 2) (500,)

# %%
plt.scatter(X[:,0],X[:,1],c=Y)
plt.show()

# %%
from keras.models import Sequential
from keras.layers import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-baceebbeac60> in <module>
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import *
#
# ModuleNotFoundError: No module named 'keras'
